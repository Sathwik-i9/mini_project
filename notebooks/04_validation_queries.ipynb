-- %%
use catalog hive_metastore;

-- %%
-- DROP ALL TABLES
DROP TABLE IF EXISTS patient_final_silver;
DROP TABLE IF EXISTS patient_dim;

DROP TABLE IF EXISTS insurance_final_silver;
DROP TABLE IF EXISTS insurance_dim;

DROP TABLE IF EXISTS mini_proj_logs.etl_log;

-- %%
%python
paths = [
    "s3a://mini-project-sathwik/bronze/patient_bronze",
    "s3a://mini-project-sathwik/bronze/insurance_bronze",
    
    "s3a://mini-project-sathwik/silver/patient_prefinal_silver",
    "s3a://mini-project-sathwik/silver/patient_final_silver",
    "s3a://mini-project-sathwik/gold/patient_dim",
    
    "s3a://mini-project-sathwik/silver/insurance_prefinal_silver",
    "s3a://mini-project-sathwik/silver/insurance_final_silver",
    "s3a://mini-project-sathwik/gold/insurance_dim",

    "s3a://mini-project-sathwik/logs/etl_log"
]

for p in paths:
    dbutils.fs.rm(p, recurse=True)

-- %% [markdown]
-- Code to reset everything

-- %%
use mini_proj_logs

-- %%
drop table if exists mini_proj_logs;

-- %%
use mini_proj_silver

-- %%
drop table if exists patient_final_silver_accessible;
drop table if exists insurance_final_silver_accessible;
drop table if exists patient_silver_metrics;
drop table if exists insurance_silver_metrics

-- %%
use mini_proj_gold;

-- %%
drop table if exists patient_dim_accessible;
drop table if exists insurance_dim_accessible;
drop table if exists patient_gold_metrics;
drop table if exists insurance_gold_metrics

-- %%
use mini_proj_bronze;

-- %%
drop table if exists patient_bronze;
drop table if exists insurance_bronze;

-- %%
use mini_proj_metrics

-- %%
drop table if exists dq_patient_bronze_metrics;
drop table if exists dq_insurance_bronze_metrics;

-- %%
create database if not exists mini_proj_bronze;

-- %%
%python
df=spark.table("patient_bronze")
df.write.format("delta").mode("overwrite").saveAsTable("mini_proj_bronze.patient_bronze")

-- %%
%python
df=spark.table("insurance_bronze")
df.write.format("delta").mode("overwrite").saveAsTable("mini_proj_bronze.insurance_bronze")
