# %%
spark._jsc.hadoopConfiguration().set("fs.s3a.access.key", "AKIAXQZZTZYPDL4MM2UI")
spark._jsc.hadoopConfiguration().set("fs.s3a.secret.key", "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")
spark._jsc.hadoopConfiguration().set("fs.s3a.endpoint", "s3.amazonaws.com")

# %%
dbutils.fs.ls("s3a://mini-project-sathwik/logs/")

# %%
df = spark.createDataFrame([(1, "hello")], ["id", "value"])
df.write.mode("overwrite").parquet("s3a://mini-project-sathwik/test-folder/")

# %%
df2 = spark.read.parquet("s3a://mini-project-sathwik/test-folder/")
df2.show()

# %%
dbutils.fs.mkdirs("s3a://mini-project-sathwik/bronze")
dbutils.fs.mkdirs("s3a://mini-project-sathwik/silver")
dbutils.fs.mkdirs("s3a://mini-project-sathwik/gold")
dbutils.fs.mkdirs("s3a://mini-project-sathwik/logs")
dbutils.fs.mkdirs("s3a://mini-project-sathwik/raw/patient")
dbutils.fs.mkdirs("s3a://mini-project-sathwik/raw/insurance")
